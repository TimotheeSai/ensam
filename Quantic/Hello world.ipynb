# %% [markdown]
# # Hello World

# %%
import numpy as np
from qiskit import *
# %matplotlib inline

# %% [markdown]
# On initialise deux qubits et  deux bits classiques puis on créé un circuit

# %%
qr = QuantumRegister(2)
cr = ClassicalRegister(2)
circuit = QuantumCircuit(qr, cr)

# %%
circuit.draw(output='mpl')

# %% [markdown]
# Creation d'une porte Hademar

# %%
# the quantum circuit has two qubits. they are indexed as qubits 0 and 1
circuit.h(qr[0])

# %%
circuit.cx(qr[0], qr[1]) # order is control, target, controle x <=> logical if
circuit.measure(qr, cr) # qubits [0,1] are measured and results are stored in classical bits [0,1] in order
circuit.draw(output='mpl')

# %% [markdown]
# ### Execution dans un simulateur

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(circuit, backend=simulator).result()

# %%
from qiskit.visualization import plot_histogram

# %%
plot_histogram(result.get_counts(circuit))
